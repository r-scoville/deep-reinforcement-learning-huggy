# %% [markdown]
# <a href="https://colab.research.google.com/github/r-scoville/deep-reinforcement-learning-huggy/blob/main/huggy_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning Agent (Huggy)
# ## <Model Type>
#
# ---

# %% [markdown]
# November 2025
# R. Scoville

# %% [markdown]
# ### About
#
# This notebook creates, trains, and evaluates a deep reinforcement learning agent.
#
# - Environment: Huggy the Dog (created by [Thomas Simonini](https://huggingface.co/spaces/ThomasSimonini/) based on [Puppo The Corgi](https://blog.unity.com/technology/puppo-the-corgi-cuteness-overload-with-the-unity-ml-agents-toolkit))
# - RL library: [ML-Agents](https://github.com/Unity-Technologies/ml-agents)

# %% [markdown]
# ### References
# - [Hugging Face: Deep Reinforcement Learning Course, Bonus Unit 1](https://huggingface.co/learn/deep-rl-course/unitbonus1/introduction)
# - [ML-Agents Training Configuration](https://github.com/Unity-Technologies/ml-agents/blob/main/docs/Training-Configuration-File.md)

# %% [markdown]
# ---
# ## 1. Set the GPU
# This will accelerate the agent's training.
# `Runtime > Change runtime type > Hardware accelerator > T4 GPU`

# %% [markdown]
# ---
#
# ## 2. Clone the ML-Agents repository

# %%
# %%capture
# Clone the repository (can take 3min)
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents

# %% [markdown]
# ---
#
# ## 3. Set up the virtual environment
#
# In order for the ML-Agents to run successfully in Colab, Colab's Python version must meet the library's Python requirements.
#
# We can check for the supported Python version under the `python_requires` parameter in the setup.py files. These files are required to set up the ML-Agents library for use and can be found in the following locations:
#
# - [`/content/ml-agents/ml-agents/setup.py`](https://github.com/Unity-Technologies/ml-agents/blob/develop/ml-agents/setup.py)
# - [`/content/ml-agents/ml-agents-envs/setup.py`](https://github.com/Unity-Technologies/ml-agents/blob/develop/ml-agents-envs/setup.py)
#
# To resolve incompatibility errors, create a virtual environment with a Python version compatible with the ML-Agents library.
#
# ML-Agents library's Python requirement at the time of this script's creation:
# `>= 3.10.1, <= 3.10.12`

# %%
# Check Colab's current Python version (incompatible with ML-Agents)
# !python --version
# Out:
# Python 3.10.12

# %%
# Install virtualenv and create a virtual environment
# !pip install virtualenv
# !virtualenv myenv

# Download and install Miniconda
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local

# Activate Miniconda and install Python ver 3.10.12
# !source /usr/local/bin/activate
# !conda install -q -y --prefix /usr/local python=3.10.12 ujson  # Specify the version here

# Set environment variables for Python and conda paths
# !export PYTHONPATH=/usr/local/lib/python3.10/site-packages/
# !export CONDA_PREFIX=/usr/local/envs/myenv
# Out:
# Collecting virtualenv
#   Using cached virtualenv-20.35.4-py3-none-any.whl.metadata (4.6 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv)
#   Using cached distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting filelock<4,>=3.12.2 (from virtualenv)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.13/site-packages (from virtualenv) (4.3.7)
# Using cached virtualenv-20.35.4-py3-none-any.whl (6.0 MB)
# Using cached distlib-0.4.0-py2.py3-none-any.whl (469 kB)
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Installing collected packages: distlib, filelock, virtualenv
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [virtualenv]
# Successfully installed distlib-0.4.0 filelock-3.20.0 virtualenv-20.35.4
# created virtual environment CPython3.13.9.final.0-64 in 574ms
#   creator CPython3Posix(dest=/content/myenv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.3
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
# --2025-11-11 17:28:16--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156323998 (149M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh.1’
#
# Miniconda3-latest-L 100%[===================>] 149.08M  79.1MB/s    in 1.9s
#
# 2025-11-11 17:28:18 (79.1 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh.1’ saved [156323998/156323998]
#
# PREFIX=/usr/local
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Jupyter detected...
# 2 channel Terms of Service accepted
# Retrieving notices: ...working... done
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - python=3.10.12
#     - ujson
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-anon-usage-0.7.4  |   pyhb46e38b_100          19 KB
#     anaconda-auth-0.10.0       |  py310h06a4308_1          69 KB
#     anaconda-cli-base-0.6.0    |  py310h06a4308_0          39 KB
#     annotated-types-0.6.0      |  py310h06a4308_1          22 KB
#     backports.tarfile-1.2.0    |  py310h06a4308_0          55 KB
#     boltons-25.0.0             |  py310h06a4308_0         429 KB
#     brotlicffi-1.0.9.2         |  py310hbdd6827_2         325 KB
#     ca-certificates-2025.11.4  |       h06a4308_0         128 KB
#     certifi-2025.10.5          |  py310h06a4308_0         157 KB
#     cffi-2.0.0                 |  py310h4eded50_1         237 KB
#     click-8.1.8                |  py310h06a4308_0         274 KB
#     conda-25.9.1               |  py310h06a4308_0         932 KB
#     conda-anaconda-tos-0.2.2   |  py310h06a4308_1          40 KB
#     conda-content-trust-0.2.0  |  py310h06a4308_1          51 KB
#     conda-package-handling-2.4.0|  py310h06a4308_1         269 KB
#     conda-package-streaming-0.12.0|  py310h06a4308_1          31 KB
#     cryptography-46.0.3        |  py310h0a354b3_0         1.6 MB
#     distro-1.9.0               |  py310h06a4308_0          31 KB
#     frozendict-2.4.6           |  py310hee96239_0          57 KB
#     idna-3.11                  |  py310h06a4308_0         196 KB
#     importlib-metadata-8.5.0   |  py310h06a4308_0          45 KB
#     jaraco.classes-3.4.0       |  py310h06a4308_0          18 KB
#     jaraco.context-6.0.0       |  py310h06a4308_0          15 KB
#     jaraco.functools-4.1.0     |  py310h06a4308_0          20 KB
#     jsonpatch-1.33             |  py310h06a4308_1          31 KB
#     jsonpointer-3.0.0          |  py310h06a4308_0          19 KB
#     keyring-25.6.0             |  py310h06a4308_0          69 KB
#     libmambapy-2.3.2           |  py310hea2f153_0         646 KB
#     markdown-it-py-4.0.0       |  py310h06a4308_0         219 KB
#     mdurl-0.1.2                |  py310h06a4308_0          23 KB
#     menuinst-2.4.1             |  py310h06a4308_1         223 KB
#     more-itertools-10.8.0      |  py310h06a4308_0         137 KB
#     packaging-25.0             |  py310h06a4308_1         164 KB
#     pkce-1.0.3                 |  py310h06a4308_0           8 KB
#     platformdirs-4.5.0         |  py310h06a4308_0          37 KB
#     pluggy-1.5.0               |  py310h06a4308_0          37 KB
#     pybind11-abi-4             |       hd3eb1b0_1          14 KB
#     pycosat-0.6.6              |  py310h5eee18b_2          88 KB
#     pycparser-2.23             |  py310h06a4308_0         227 KB
#     pydantic-2.12.3            |  py310h06a4308_1         887 KB
#     pydantic-core-2.41.4       |  py310h498d7c9_0         1.8 MB
#     pydantic-settings-2.10.1   |  py310h06a4308_0         103 KB
#     pygments-2.19.2            |  py310h06a4308_0         4.5 MB
#     pyjwt-2.10.1               |  py310h06a4308_0          75 KB
#     pysocks-1.7.1              |  py310h06a4308_1          29 KB
#     python-3.10.12             |       h955ad1f_0        26.8 MB
#     python-dotenv-1.1.0        |  py310h06a4308_0          40 KB
#     readchar-4.2.1             |  py310h06a4308_0          19 KB
#     requests-2.32.5            |  py310h06a4308_1         141 KB
#     rich-14.2.0                |  py310h06a4308_0         473 KB
#     ruamel.yaml-0.18.16        |  py310h4aee224_0         199 KB
#     ruamel.yaml.clib-0.2.14    |  py310h4aee224_0         133 KB
#     secretstorage-3.4.0        |  py310h3e8c6aa_0          26 KB
#     semver-3.0.4               |  py310h06a4308_0          38 KB
#     setuptools-80.9.0          |  py310h06a4308_0         1.4 MB
#     shellingham-1.5.4          |  py310h06a4308_0          19 KB
#     tomli-2.2.1                |  py310h06a4308_0          29 KB
#     tqdm-4.67.1                |  py310h7040dfc_1         131 KB
#     truststore-0.10.1          |  py310h06a4308_1          40 KB
#     typer-0.17.4               |  py310h06a4308_0         124 KB
#     typing-extensions-4.15.0   |  py310h06a4308_0          11 KB
#     typing-inspection-0.4.2    |  py310h06a4308_0          27 KB
#     typing_extensions-4.15.0   |  py310h06a4308_0          80 KB
#     ujson-5.10.0               |  py310h6a678d5_1         141 KB
#     urllib3-2.5.0              |  py310h06a4308_0         308 KB
#     wheel-0.45.1               |  py310h06a4308_0         115 KB
#     zipp-3.21.0                |  py310h06a4308_0          27 KB
#     zstandard-0.24.0           |  py310h3d778a8_0         397 KB
#     ------------------------------------------------------------
#                                            Total:        45.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   backports.tarfile  pkgs/main/linux-64::backports.tarfile-1.2.0-py310h06a4308_0
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-8.5.0-py310h06a4308_0
#   ujson              pkgs/main/linux-64::ujson-5.10.0-py310h6a678d5_1
#   zipp               pkgs/main/linux-64::zipp-3.21.0-py310h06a4308_0
#
# The following packages will be REMOVED:
#
#   libmpdec-4.0.0-h5eee18b_0
#   python_abi-3.13-1_cp313
#
# The following packages will be UPDATED:
#
#   anaconda-anon-usa~ pkgs/main/linux-64::anaconda-anon-usa~ --> pkgs/main/noarch::anaconda-anon-usage-0.7.4-pyhb46e38b_100
#   anaconda-cli-base                   0.5.4-py313h06a4308_0 --> 0.6.0-py310h06a4308_0
#   annotated-types                     0.6.0-py313h06a4308_0 --> 0.6.0-py310h06a4308_1
#   brotlicffi                        1.0.9.2-py313h6a678d5_1 --> 1.0.9.2-py310hbdd6827_2
#   ca-certificates                       2025.9.9-h06a4308_0 --> 2025.11.4-h06a4308_0
#   cffi                                2.0.0-py313h4eded50_0 --> 2.0.0-py310h4eded50_1
#   conda-package-han~                  2.4.0-py313h06a4308_0 --> 2.4.0-py310h06a4308_1
#   conda-package-str~                 0.12.0-py313h06a4308_0 --> 0.12.0-py310h06a4308_1
#   cryptography                       46.0.2-py313h498d7c9_0 --> 46.0.3-py310h0a354b3_0
#   frozendict                          2.4.2-py313h06a4308_0 --> 2.4.6-py310hee96239_0
#   idna                                  3.7-py313h06a4308_0 --> 3.11-py310h06a4308_0
#   menuinst                            2.3.1-py313h06a4308_0 --> 2.4.1-py310h06a4308_1
#   platformdirs                        4.3.7-py313h06a4308_0 --> 4.5.0-py310h06a4308_0
#   pydantic                           2.12.2-py313h06a4308_0 --> 2.12.3-py310h06a4308_1
#   pygments                           2.19.1-py313h06a4308_0 --> 2.19.2-py310h06a4308_0
#   pysocks                             1.7.1-py313h06a4308_0 --> 1.7.1-py310h06a4308_1
#   requests                           2.32.5-py313h06a4308_0 --> 2.32.5-py310h06a4308_1
#   ruamel.yaml                       0.18.10-py313h5eee18b_0 --> 0.18.16-py310h4aee224_0
#   ruamel.yaml.clib                   0.2.12-py313h5eee18b_0 --> 0.2.14-py310h4aee224_0
#   semver                              3.0.2-py313h06a4308_1 --> 3.0.4-py310h06a4308_0
#   shellingham                         1.5.0-py313h06a4308_0 --> 1.5.4-py310h06a4308_0
#   tqdm                               4.67.1-py313h7040dfc_0 --> 4.67.1-py310h7040dfc_1
#   truststore                         0.10.1-py313h06a4308_0 --> 0.10.1-py310h06a4308_1
#
# The following packages will be DOWNGRADED:
#
#   pybind11-abi                                 5-hd3eb1b0_0 --> 4-hd3eb1b0_1
#   python                          3.13.9-h7e8bc2b_100_cp313 --> 3.10.12-h955ad1f_0
#
# The following packages will be REVISED:
#
#   anaconda-auth                      0.10.0-py313h06a4308_1 --> 0.10.0-py310h06a4308_1
#   boltons                            25.0.0-py313h06a4308_0 --> 25.0.0-py310h06a4308_0
#   certifi                         2025.10.5-py313h06a4308_0 --> 2025.10.5-py310h06a4308_0
#   click                               8.1.8-py313h06a4308_0 --> 8.1.8-py310h06a4308_0
#   conda                              25.9.1-py313h06a4308_0 --> 25.9.1-py310h06a4308_0
#   conda-anaconda-tos                  0.2.2-py313h06a4308_1 --> 0.2.2-py310h06a4308_1
#   conda-content-tru~                  0.2.0-py313h06a4308_1 --> 0.2.0-py310h06a4308_1
#   distro                              1.9.0-py313h06a4308_0 --> 1.9.0-py310h06a4308_0
#   jaraco.classes                      3.4.0-py313h06a4308_0 --> 3.4.0-py310h06a4308_0
#   jaraco.context                      6.0.0-py313h06a4308_0 --> 6.0.0-py310h06a4308_0
#   jaraco.functools                    4.1.0-py313h06a4308_0 --> 4.1.0-py310h06a4308_0
#   jsonpatch                            1.33-py313h06a4308_1 --> 1.33-py310h06a4308_1
#   jsonpointer                         3.0.0-py313h06a4308_0 --> 3.0.0-py310h06a4308_0
#   keyring                            25.6.0-py313h06a4308_0 --> 25.6.0-py310h06a4308_0
#   libmambapy                          2.3.2-py313hea2f153_0 --> 2.3.2-py310hea2f153_0
#   markdown-it-py                      4.0.0-py313h06a4308_0 --> 4.0.0-py310h06a4308_0
#   mdurl                               0.1.2-py313h06a4308_0 --> 0.1.2-py310h06a4308_0
#   more-itertools                     10.8.0-py313h06a4308_0 --> 10.8.0-py310h06a4308_0
#   packaging                            25.0-py313h06a4308_1 --> 25.0-py310h06a4308_1
#   pkce                                1.0.3-py313h06a4308_0 --> 1.0.3-py310h06a4308_0
#   pluggy                              1.5.0-py313h06a4308_0 --> 1.5.0-py310h06a4308_0
#   pycosat                             0.6.6-py313h5eee18b_2 --> 0.6.6-py310h5eee18b_2
#   pycparser                            2.23-py313h06a4308_0 --> 2.23-py310h06a4308_0
#   pydantic-core                      2.41.4-py313h498d7c9_0 --> 2.41.4-py310h498d7c9_0
#   pydantic-settings                  2.10.1-py313h06a4308_0 --> 2.10.1-py310h06a4308_0
#   pyjwt                              2.10.1-py313h06a4308_0 --> 2.10.1-py310h06a4308_0
#   python-dotenv                       1.1.0-py313h06a4308_0 --> 1.1.0-py310h06a4308_0
#   readchar                            4.2.1-py313h06a4308_0 --> 4.2.1-py310h06a4308_0
#   rich                               14.2.0-py313h06a4308_0 --> 14.2.0-py310h06a4308_0
#   secretstorage                       3.4.0-py313h3e8c6aa_0 --> 3.4.0-py310h3e8c6aa_0
#   setuptools                         80.9.0-py313h06a4308_0 --> 80.9.0-py310h06a4308_0
#   tomli                               2.2.1-py313h06a4308_0 --> 2.2.1-py310h06a4308_0
#   typer                              0.17.4-py313h06a4308_0 --> 0.17.4-py310h06a4308_0
#   typing-extensions                  4.15.0-py313h06a4308_0 --> 4.15.0-py310h06a4308_0
#   typing-inspection                   0.4.2-py313h06a4308_0 --> 0.4.2-py310h06a4308_0
#   typing_extensions                  4.15.0-py313h06a4308_0 --> 4.15.0-py310h06a4308_0
#   urllib3                             2.5.0-py313h06a4308_0 --> 2.5.0-py310h06a4308_0
#   wheel                              0.45.1-py313h06a4308_0 --> 0.45.1-py310h06a4308_0
#   zstandard                          0.24.0-py313h3d778a8_0 --> 0.24.0-py310h3d778a8_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... Removed 2 cache files.
# Removed 2 Terms of Service files.
#
# done

# %%
# Python version in new virtual environment (compatible with ML-Agents)
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ---
# ## 4. Install the dependencies

# %%
# %%capture
# Go inside the repository and install the package (this can take a few min.)
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %% [markdown]
# ---
# ## 5. Download and move the environment zip file
#
# The environment executable is in a zip file. Download it and move it to `./trained-envs-executables/linux/`

# %%
# Create the file's destination
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %% [markdown]
# Download the file `Huggy.zip` from `https://github.com/huggingface/Huggy` using `wget`.

# %%
# !wget "https://github.com/huggingface/Huggy/raw/main/Huggy.zip" -O ./trained-envs-executables/linux/Huggy.zip
# Out:
# --2025-11-11 17:35:27--  https://github.com/huggingface/Huggy/raw/main/Huggy.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/huggingface/Huggy/main/Huggy.zip [following]
# --2025-11-11 17:35:27--  https://media.githubusercontent.com/media/huggingface/Huggy/main/Huggy.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39214997 (37M) [application/zip]
# Saving to: ‘./trained-envs-executables/linux/Huggy.zip’
#
# ./trained-envs-exec 100%[===================>]  37.40M  70.5MB/s    in 0.5s
#
# 2025-11-11 17:35:28 (70.5 MB/s) - ‘./trained-envs-executables/linux/Huggy.zip’ saved [39214997/39214997]

# %%
# Extract the file
# %%capture
# !unzip -d ./trained-envs-executables/linux/ ./trained-envs-executables/linux/Huggy.zip

# %%
# Ensure the file is accessible
# !chmod -R 755 ./trained-envs-executables/linux/Huggy

# %% [markdown]
# ---
#
# ## 🌐 Environment Overview
#
# ### State Space
# Huggy's state (information on its environment) informs what actions the agent takes. The state space includes:
# - The target (stick) position
# - The relative position between it and the target
# - The orientation of its legs
#
# </br>
#
# ### Action Space
# Joint motors drive Huggy's legs. To reach the target, the agent must learn to rotate the joint motors of each leg correctly to move.
#
# </br>
#
# ### Reward Function
# The reinforcement learning reward function follows the *reward hypothesis*:
# A goal can be described as the maximization of the expected cumulative reward.
# This reward function translates the agent's goal of reaching the stick without spinning too much:
# - **Bonus for reaching the target**: positive reward for achieving the goal
# - **Orientation bonus**: positive reward for getting closer to the target
# - **Time penalty**: A fixed-time penalty (negative reward) given at every action if the agent has not reached the target
# - **Rotation penalty**: Negative reward for spinning too much and turning too quickly

# %% [markdown]
# ---
# ## 6. Create the Huggy config file
# Define the training hyperparameters within the `Huggy.yaml` config file located at `/content/ml-agents/config/ppo`.
#
# More information on hyperparameter tuning: [`/content/ml-agents/docs/training-configuration-file.md`](https://github.com/Unity-Technologies/ml-agents/blob/main/docs/Training-Configuration-File.md)

# %%
# Copy and paste the following into the new Huggy.yaml file
behaviors:
  Huggy:
    trainer_type: ppo
    hyperparameters:
      batch_size: 2048
      buffer_size: 20480
      learning_rate: 0.0003
      beta: 0.005
      epsilon: 0.2
      lambd: 0.95
      num_epoch: 3
      learning_rate_schedule: linear
    network_settings:
      normalize: true
      hidden_units: 512
      num_layers: 3
      vis_encode_type: simple
    reward_signals:
      extrinsic:
        gamma: 0.995
        strength: 1.0
    checkpoint_interval: 200000
    keep_checkpoints: 15
    max_steps: 2e6
    time_horizon: 1000
    summary_freq: 50000

# %% [markdown]
# ---
# ## 7. Train the agent
# Launch `mlagents-learn` and select the executable containing the environment.
#
# With ML Agents, run a training script and define four parameters:
#
# 1. `mlagents-learn <config>`: the path where the hyperparameter config file is
# 2. `--env`: where the environment executable is
# 3. `--run-id`: the name you want to give to your training run ID
# 4. `--no-graphics`: to not launch the visualization during the training
#
# Train the model and use the `--resume` flag to continue training in case of interruption. It will fail first time when you use `--resume`. Try running the block again to bypass the error.
#
# The training should take 30 to 45 min. depending on the machine/whether the runtime type is GPU.

# %%
# !mlagents-learn ./config/ppo/Huggy.yaml --env=./trained-envs-executables/linux/Huggy/Huggy --run-id="Huggy2" --no-graphics
# Out:
# /content/ml-agents/ml-agents/mlagents/torch_utils/torch.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.2.0.dev0,
#   ml-agents-envs: 1.2.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.8.0+cu128
# [INFO] Connected to Unity environment with package version 2.2.1-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: Huggy?team=0
# [INFO] Hyperparameters for behavior name Huggy:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	2048
# 	  buffer_size:	20480
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	200000
# 	network_settings:
# 	  normalize:	True
# 	  hidden_units:	512
# 	  num_layers:	3
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.995
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	15
# 	even_checkpoints:	False
# 	max_steps:	2000000
# 	time_horizon:	1000
# 	summary_freq:	50000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Huggy. Step: 50000. Time Elapsed: 109.980 s. Mean Reward: 1.800. Std of Reward: 0.916. Training.
# [INFO] Huggy. Step: 100000. Time Elapsed: 211.973 s. Mean Reward: 2.565. Std of Reward: 1.027. Training.
# [INFO] Huggy. Step: 150000. Time Elapsed: 324.524 s. Mean Reward: 3.110. Std of Reward: 1.283. Training.
# [INFO] Huggy. Step: 200000. Time Elapsed: 424.448 s. Mean Reward: 3.339. Std of Reward: 1.304. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-199713.onnx
# [INFO] Huggy. Step: 250000. Time Elapsed: 540.023 s. Mean Reward: 3.653. Std of Reward: 1.446. Training.
# [INFO] Huggy. Step: 300000. Time Elapsed: 649.136 s. Mean Reward: 3.584. Std of Reward: 1.562. Training.
# [INFO] Huggy. Step: 350000. Time Elapsed: 750.221 s. Mean Reward: 3.695. Std of Reward: 1.559. Training.
# [INFO] Huggy. Step: 400000. Time Elapsed: 865.611 s. Mean Reward: 3.712. Std of Reward: 1.539. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-399962.onnx
# [INFO] Huggy. Step: 450000. Time Elapsed: 967.434 s. Mean Reward: 3.732. Std of Reward: 1.774. Training.
# [INFO] Huggy. Step: 500000. Time Elapsed: 1080.495 s. Mean Reward: 3.516. Std of Reward: 1.909. Training.
# [INFO] Huggy. Step: 550000. Time Elapsed: 1185.944 s. Mean Reward: 3.815. Std of Reward: 2.032. Training.
# [INFO] Huggy. Step: 600000. Time Elapsed: 1296.168 s. Mean Reward: 3.803. Std of Reward: 1.938. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-599983.onnx
# [INFO] Huggy. Step: 650000. Time Elapsed: 1395.195 s. Mean Reward: 3.562. Std of Reward: 1.917. Training.
# [INFO] Huggy. Step: 700000. Time Elapsed: 1498.049 s. Mean Reward: 3.692. Std of Reward: 2.048. Training.
# [INFO] Huggy. Step: 750000. Time Elapsed: 1610.689 s. Mean Reward: 3.572. Std of Reward: 2.039. Training.
# [INFO] Huggy. Step: 800000. Time Elapsed: 1712.308 s. Mean Reward: 3.684. Std of Reward: 1.973. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-799927.onnx
# [INFO] Huggy. Step: 850000. Time Elapsed: 1829.743 s. Mean Reward: 3.519. Std of Reward: 1.979. Training.
# [INFO] Huggy. Step: 900000. Time Elapsed: 1931.407 s. Mean Reward: 3.688. Std of Reward: 2.014. Training.
# [INFO] Huggy. Step: 950000. Time Elapsed: 2047.518 s. Mean Reward: 3.808. Std of Reward: 2.043. Training.
# [INFO] Huggy. Step: 1000000. Time Elapsed: 2152.251 s. Mean Reward: 3.772. Std of Reward: 2.026. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-999877.onnx
# [INFO] Huggy. Step: 1050000. Time Elapsed: 2258.329 s. Mean Reward: 3.692. Std of Reward: 2.115. Training.
# [INFO] Huggy. Step: 1100000. Time Elapsed: 2373.007 s. Mean Reward: 3.489. Std of Reward: 2.072. Training.
# [INFO] Huggy. Step: 1150000. Time Elapsed: 2477.320 s. Mean Reward: 3.627. Std of Reward: 2.168. Training.
# [INFO] Huggy. Step: 1200000. Time Elapsed: 2590.356 s. Mean Reward: 3.759. Std of Reward: 2.087. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-1199952.onnx
# [INFO] Huggy. Step: 1250000. Time Elapsed: 2695.021 s. Mean Reward: 3.597. Std of Reward: 2.092. Training.
# [INFO] Huggy. Step: 1300000. Time Elapsed: 2808.588 s. Mean Reward: 3.573. Std of Reward: 2.010. Training.
# [INFO] Huggy. Step: 1350000. Time Elapsed: 2910.810 s. Mean Reward: 3.677. Std of Reward: 2.103. Training.
# [INFO] Huggy. Step: 1400000. Time Elapsed: 3013.883 s. Mean Reward: 3.714. Std of Reward: 2.086. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-1399699.onnx
# [INFO] Huggy. Step: 1450000. Time Elapsed: 3129.091 s. Mean Reward: 3.683. Std of Reward: 1.977. Training.
# [INFO] Huggy. Step: 1500000. Time Elapsed: 3233.940 s. Mean Reward: 3.617. Std of Reward: 2.043. Training.
# [INFO] Huggy. Step: 1550000. Time Elapsed: 3348.525 s. Mean Reward: 3.782. Std of Reward: 2.029. Training.
# [INFO] Huggy. Step: 1600000. Time Elapsed: 3452.287 s. Mean Reward: 3.603. Std of Reward: 2.102. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-1599937.onnx
# [INFO] Huggy. Step: 1650000. Time Elapsed: 3555.692 s. Mean Reward: 3.788. Std of Reward: 2.128. Training.
# [INFO] Huggy. Step: 1700000. Time Elapsed: 3671.799 s. Mean Reward: 3.702. Std of Reward: 2.184. Training.
# [INFO] Huggy. Step: 1750000. Time Elapsed: 3771.205 s. Mean Reward: 3.719. Std of Reward: 2.155. Training.
# [INFO] Huggy. Step: 1800000. Time Elapsed: 3883.773 s. Mean Reward: 3.635. Std of Reward: 2.059. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-1799975.onnx
# [INFO] Huggy. Step: 1850000. Time Elapsed: 3989.552 s. Mean Reward: 3.703. Std of Reward: 2.060. Training.
# [INFO] Huggy. Step: 1900000. Time Elapsed: 4106.858 s. Mean Reward: 3.665. Std of Reward: 2.135. Training.
# [INFO] Huggy. Step: 1950000. Time Elapsed: 4213.065 s. Mean Reward: 3.557. Std of Reward: 2.118. Training.
# [INFO] Huggy. Step: 2000000. Time Elapsed: 4317.400 s. Mean Reward: 3.614. Std of Reward: 2.183. Training.
# [INFO] Exported results/Huggy2/Huggy/Huggy-1999925.onnx
# [INFO] Exported results/Huggy2/Huggy/Huggy-2000047.onnx
# [INFO] Copied results/Huggy2/Huggy/Huggy-2000047.onnx to results/Huggy2/Huggy.onnx.

# %% [markdown]
# ---
#
# ## 8. Push the agent to the Hugging Face Hub
#
# ### Connect to the Hub:
# 1. [Create](https://www.google.com/url?q=https%3A%2F%2Fwww.google.com%2Furl%3Fq%3Dhttps%253A%252F%252Fhuggingface.co%252Fjoin) and/or sign into an active Hugging Face account.
# 2. [Create a new token](https://www.google.com/url?q=https%3A%2F%2Fwww.google.com%2Furl%3Fq%3Dhttps%253A%252F%252Fhuggingface.co%252Fsettings%252Ftokens) with write role.
# 3. Copy the token.
# 4. Run the cell below and paste the token.
#
# Note: If not using Colab or Jupyter Notebooks, run the `huggingface-cli login` command instead.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ### Run `mlagents-push-to-hf` and define parameters:
# 1. `--run-id`: the name of the training run ID
# 2. `--local-dir`: results/<where the agent was saved\>, e.g., results/First Training
# 3. `--repo-id`: the name of the Hugging Face repo you want to create or update (Note: If the repo does not exist it will be created automatically.)
# 4. `--commit-message`: the commit message (HF repos are git repositories)

# %%
# !mlagents-push-to-hf --run-id="HuggyTraining" --local-dir="./results/Huggy2" --repo-id="r-scoville/huggy-ppo" --commit-message="First Huggy PPO agent training complete."
# Out:
# [INFO] This function will create a model card and upload your HuggyTraining into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo HuggyTraining to the Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   .../Huggy/Huggy-1199952.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt:   6% 748k/13.5M [00:00<?, ?B/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt:   6% 748k/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt:   2% 209k/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#   ...y2/Huggy/Huggy-1999925.pt:   5% 652k/13.5M [00:00<?, ?B/s]
#
#   .../Huggy/Huggy-1199952.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt:   6% 748k/13.5M [00:00<?, ?B/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt:   6% 748k/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt:   2% 209k/13.5M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx:   6% 126k/2.27M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :   3% 5.98M/190M [00:02<01:27, 2.10MB/s, 2.40MB/s  ]
# New Data Upload               :   3% 4.51M/163M [00:02<01:40, 1.58MB/s, 1.81MB/s  ]
#
#   .../Huggy/Huggy-1199952.onnx:  20% 462k/2.27M [00:00<00:01, 1.68MB/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt:  20% 2.74M/13.5M [00:00<00:01, 9.98MB/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx:  20% 462k/2.27M [00:00<00:01, 1.68MB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt:  20% 2.74M/13.5M [00:00<00:01, 9.99MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx:  20% 462k/2.27M [00:00<00:01, 1.68MB/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx:  20% 462k/2.27M [00:00<00:01, 1.68MB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx:  20% 462k/2.27M [00:00<00:01, 1.68MB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt:  19% 2.53M/13.5M [00:00<00:00, 11.6MB/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx:  20% 462k/2.27M [00:00<00:01, 1.68MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  17% 31.4M/190M [00:03<00:11, 13.5MB/s, 11.7MB/s  ]
# New Data Upload               :  16% 26.0M/163M [00:03<00:12, 11.2MB/s, 9.65MB/s  ]
#
#   .../Huggy/Huggy-1199952.onnx:  37% 839k/2.27M [00:00<00:00, 1.79MB/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt:  37% 4.99M/13.5M [00:00<00:00, 10.6MB/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx:  37% 839k/2.27M [00:00<00:00, 1.79MB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt:  37% 4.99M/13.5M [00:00<00:00, 10.6MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx:  37% 839k/2.27M [00:00<00:00, 1.79MB/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx:  37% 839k/2.27M [00:00<00:00, 1.79MB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx:  37% 839k/2.27M [00:00<00:00, 1.79MB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt:  38% 5.10M/13.5M [00:00<00:00, 12.3MB/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx:  37% 839k/2.27M [00:00<00:00, 1.79MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  31% 59.6M/190M [00:03<00:04, 28.2MB/s, 20.6MB/s  ]
# New Data Upload               :  31% 49.8M/163M [00:03<00:04, 23.6MB/s, 17.2MB/s  ]
#
#   .../Huggy/Huggy-1199952.onnx:  53% 1.20M/2.27M [00:00<00:00, 1.79MB/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt:  53% 7.11M/13.5M [00:00<00:00, 10.6MB/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx:  53% 1.20M/2.27M [00:00<00:00, 1.78MB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt:  53% 7.11M/13.5M [00:00<00:00, 10.6MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx:  53% 1.20M/2.27M [00:00<00:00, 1.78MB/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx:  53% 1.20M/2.27M [00:00<00:00, 1.78MB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx:  53% 1.20M/2.27M [00:00<00:00, 1.79MB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt:  60% 8.09M/13.5M [00:00<00:00, 13.1MB/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx:  53% 1.20M/2.27M [00:00<00:00, 1.79MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  47% 88.7M/190M [00:03<00:02, 44.7MB/s, 28.7MB/s  ]
# New Data Upload               :  46% 74.7M/163M [00:03<00:02, 37.8MB/s, 24.1MB/s  ]
#
#   .../Huggy/Huggy-1199952.onnx:  69% 1.57M/2.27M [00:00<00:00, 1.81MB/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt:  69% 9.35M/13.5M [00:00<00:00, 10.8MB/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx:  69% 1.57M/2.27M [00:00<00:00, 1.81MB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt:  69% 9.35M/13.5M [00:00<00:00, 10.8MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx:  69% 1.57M/2.27M [00:00<00:00, 1.81MB/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx:  69% 1.57M/2.27M [00:00<00:00, 1.81MB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx:  69% 1.57M/2.27M [00:00<00:00, 1.81MB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt:  79% 10.7M/13.5M [00:00<00:00, 13.1MB/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx:  69% 1.57M/2.27M [00:00<00:00, 1.81MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  62% 117M/190M [00:03<00:01, 60.9MB/s, 35.5MB/s  ]
# New Data Upload               :  60% 98.4M/163M [00:03<00:01, 51.4MB/s, 29.9MB/s  ]
#
#   .../Huggy/Huggy-1199952.onnx:  87% 1.97M/2.27M [00:00<00:00, 1.85MB/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt:  87% 11.7M/13.5M [00:00<00:00, 11.0MB/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx:  87% 1.97M/2.27M [00:00<00:00, 1.85MB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt:  87% 11.7M/13.5M [00:00<00:00, 11.0MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx:  87% 1.97M/2.27M [00:00<00:00, 1.85MB/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx:  87% 1.97M/2.27M [00:00<00:00, 1.85MB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx:  87% 1.97M/2.27M [00:00<00:00, 1.85MB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt:  98% 13.2M/13.5M [00:00<00:00, 13.1MB/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx:  87% 1.97M/2.27M [00:00<00:00, 1.85MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  77% 147M/190M [00:03<00:00, 77.8MB/s, 41.9MB/s  ]
# New Data Upload               :  76% 123M/163M [00:03<00:00, 65.6MB/s, 35.3MB/s  ]
#
#   .../Huggy/Huggy-1199952.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.79MB/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt: 100% 13.5M/13.5M [00:01<00:00, 10.6MB/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.79MB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt: 100% 13.5M/13.5M [00:01<00:00, 10.6MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.79MB/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.79MB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.79MB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt: 100% 13.5M/13.5M [00:01<00:00, 11.1MB/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.79MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  84% 160M/190M [00:04<00:00, 75.6MB/s, 43.3MB/s  ]
# New Data Upload               :  82% 133M/163M [00:04<00:00, 62.4MB/s, 36.1MB/s  ]
#
#   .../Huggy/Huggy-1199952.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.53MB/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt: 100% 13.5M/13.5M [00:01<00:00, 9.08MB/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.53MB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt: 100% 13.5M/13.5M [00:01<00:00, 9.09MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.53MB/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.53MB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.53MB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt: 100% 13.5M/13.5M [00:01<00:00, 9.49MB/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.53MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  85% 161M/190M [00:04<00:00, 59.1MB/s, 41.4MB/s  ]
# New Data Upload               :  83% 135M/163M [00:04<00:00, 48.9MB/s, 34.6MB/s  ]
#
#   .../Huggy/Huggy-1199952.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.34MB/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt: 100% 13.5M/13.5M [00:01<00:00, 7.95MB/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.34MB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt: 100% 13.5M/13.5M [00:01<00:00, 7.95MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.34MB/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.34MB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.34MB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt: 100% 13.5M/13.5M [00:01<00:00, 8.30MB/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.34MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (0 / 25)     :  86% 164M/190M [00:04<00:00, 47.7MB/s, 40.1MB/s  ]
# New Data Upload               :  84% 137M/163M [00:04<00:00, 40.1MB/s, 33.6MB/s  ]
#
#   .../Huggy/Huggy-1199952.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.19MB/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt: 100% 13.5M/13.5M [00:01<00:00, 7.07MB/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.19MB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt: 100% 13.5M/13.5M [00:01<00:00, 7.07MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.19MB/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.19MB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.19MB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt: 100% 13.5M/13.5M [00:01<00:00, 7.39MB/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.19MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (7 / 25)     :  87% 165M/190M [00:04<00:00, 36.7MB/s, 38.5MB/s  ]
# New Data Upload               :  85% 139M/163M [00:04<00:00, 31.2MB/s, 32.3MB/s  ]
#
#   .../Huggy/Huggy-1199952.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.07MB/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt: 100% 13.5M/13.5M [00:01<00:00, 6.36MB/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.07MB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt: 100% 13.5M/13.5M [00:01<00:00, 6.36MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.07MB/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.07MB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.07MB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt: 100% 13.5M/13.5M [00:01<00:00, 6.65MB/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.07MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (7 / 25)     :  89% 168M/190M [00:04<00:00, 30.5MB/s, 37.4MB/s  ]
# New Data Upload               :  87% 141M/163M [00:04<00:00, 26.4MB/s, 31.5MB/s  ]
#
#   .../Huggy/Huggy-1199952.onnx: 100% 2.27M/2.27M [00:02<00:00, 977kB/s]
#
#
#   ...y2/Huggy/Huggy-1199952.pt: 100% 13.5M/13.5M [00:02<00:00, 5.80MB/s]
#
#
#
#   .../Huggy/Huggy-1399699.onnx: 100% 2.27M/2.27M [00:02<00:00, 977kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-1399699.pt: 100% 13.5M/13.5M [00:02<00:00, 5.80MB/s]
#
#
#
#
#
#   .../Huggy/Huggy-1599937.onnx: 100% 2.27M/2.27M [00:02<00:00, 977kB/s]
#
#
#
#
#
#
#   .../Huggy/Huggy-1799975.onnx: 100% 2.27M/2.27M [00:02<00:00, 977kB/s]
#
#
#
#
#
#
#
#   ...2/Huggy/Huggy-199713.onnx: 100% 2.27M/2.27M [00:02<00:00, 977kB/s]
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-199713.pt: 100% 13.5M/13.5M [00:02<00:00, 6.05MB/s]
#
#
#
#
#
#
#
#
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:02<00:00, 977kB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 25)    :  90% 171M/190M [00:05<00:00, 25.5MB/s, 36.4MB/s  ]
# New Data Upload               :  88% 144M/163M [00:05<00:00, 22.5MB/s, 30.7MB/s  ]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:02<00:00, 895kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:02<00:00, 5.32MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:02<00:00, 895kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:02<00:00, 5.32MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:02<00:00, 895kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  62% 8.37M/13.5M [00:02<00:01, 3.44MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt:  93% 12.6M/13.5M [00:02<00:00, 5.19MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:02<00:00, 861kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  56% 7.58M/13.5M [00:02<00:01, 3.11MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 25)    :  91% 172M/190M [00:05<00:00, 19.8MB/s, 35.1MB/s  ]
# New Data Upload               :  89% 145M/163M [00:05<00:01, 17.6MB/s, 29.6MB/s  ]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:02<00:00, 826kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:02<00:00, 4.91MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:02<00:00, 826kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:02<00:00, 4.91MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:02<00:00, 826kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  68% 9.18M/13.5M [00:02<00:01, 3.48MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt:  94% 12.7M/13.5M [00:02<00:00, 4.85MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:02<00:00, 794kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  63% 8.51M/13.5M [00:02<00:01, 3.22MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 25)    :  92% 175M/190M [00:05<00:00, 18.1MB/s, 34.3MB/s  ]
# New Data Upload               :  91% 148M/163M [00:05<00:00, 16.6MB/s, 29.0MB/s  ]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:02<00:00, 767kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:02<00:00, 4.56MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:02<00:00, 767kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:02<00:00, 4.56MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:02<00:00, 767kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  72% 9.66M/13.5M [00:02<00:01, 3.41MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt:  95% 12.8M/13.5M [00:02<00:00, 4.53MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:02<00:00, 738kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  67% 9.06M/13.5M [00:02<00:01, 3.19MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 25)    :  93% 176M/190M [00:05<00:00, 15.3MB/s, 33.3MB/s  ]
# New Data Upload               :  92% 150M/163M [00:05<00:00, 14.2MB/s, 28.2MB/s  ]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:02<00:00, 716kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:02<00:00, 4.25MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:02<00:00, 716kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:02<00:00, 4.25MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:02<00:00, 716kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  77% 10.5M/13.5M [00:02<00:00, 3.45MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt:  96% 13.0M/13.5M [00:02<00:00, 4.28MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:02<00:00, 689kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  74% 9.99M/13.5M [00:02<00:01, 3.29MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 25)    :  94% 179M/190M [00:05<00:00, 14.9MB/s, 32.6MB/s  ]
# New Data Upload               :  93% 152M/163M [00:05<00:00, 14.2MB/s, 27.7MB/s  ]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:03<00:00, 671kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:03<00:00, 3.99MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:03<00:00, 671kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:03<00:00, 3.99MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:03<00:00, 671kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  81% 10.9M/13.5M [00:03<00:00, 3.38MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt:  97% 13.0M/13.5M [00:03<00:00, 4.04MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:03<00:00, 645kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  78% 10.5M/13.5M [00:03<00:00, 3.26MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 25)    :  95% 181M/190M [00:06<00:00, 13.0MB/s, 31.7MB/s  ]
# New Data Upload               :  94% 154M/163M [00:06<00:00, 12.5MB/s, 27.1MB/s  ]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:03<00:00, 632kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:03<00:00, 3.75MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:03<00:00, 632kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:03<00:00, 3.75MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:03<00:00, 632kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  86% 11.6M/13.5M [00:03<00:00, 3.37MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt:  97% 13.2M/13.5M [00:03<00:00, 3.84MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:03<00:00, 607kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  84% 11.3M/13.5M [00:03<00:00, 3.29MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 25)    :  96% 183M/190M [00:06<00:00, 12.5MB/s, 31.1MB/s  ]
# New Data Upload               :  96% 156M/163M [00:06<00:00, 12.1MB/s, 26.5MB/s  ]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:03<00:00, 597kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:03<00:00, 3.54MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:03<00:00, 597kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:03<00:00, 3.55MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:03<00:00, 597kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  92% 12.4M/13.5M [00:03<00:00, 3.41MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt:  99% 13.3M/13.5M [00:03<00:00, 3.66MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:03<00:00, 574kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  90% 12.2M/13.5M [00:03<00:00, 3.36MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 25)    :  98% 186M/190M [00:06<00:00, 13.0MB/s, 30.5MB/s  ]
# New Data Upload               :  98% 159M/163M [00:06<00:00, 12.7MB/s, 26.1MB/s  ]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:03<00:00, 565kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:03<00:00, 3.36MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:03<00:00, 565kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:03<00:00, 3.36MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:03<00:00, 565kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  95% 12.9M/13.5M [00:03<00:00, 3.36MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt:  99% 13.4M/13.5M [00:03<00:00, 3.49MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:03<00:00, 544kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  95% 12.8M/13.5M [00:03<00:00, 3.33MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 25)    :  99% 188M/190M [00:06<00:00, 11.6MB/s, 29.8MB/s  ]
# New Data Upload               :  99% 161M/163M [00:06<00:00, 11.4MB/s, 25.5MB/s  ]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:03<00:00, 537kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:03<00:00, 3.19MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:03<00:00, 537kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:03<00:00, 3.19MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:03<00:00, 537kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  99% 13.4M/13.5M [00:03<00:00, 3.31MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt: 100% 13.5M/13.5M [00:03<00:00, 3.34MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:03<00:00, 516kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  99% 13.3M/13.5M [00:03<00:00, 3.30MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 25)    : 100% 189M/190M [00:06<00:00, 10.7MB/s, 29.1MB/s  ]
# New Data Upload               : 100% 162M/163M [00:06<00:00, 10.5MB/s, 25.0MB/s  ]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:04<00:00, 511kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:04<00:00, 3.04MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:04<00:00, 511kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:04<00:00, 3.04MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:04<00:00, 512kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  99% 13.4M/13.5M [00:04<00:00, 3.15MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt: 100% 13.5M/13.5M [00:04<00:00, 3.18MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:04<00:00, 492kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  99% 13.3M/13.5M [00:04<00:00, 3.15MB/s]
#
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-799927.pt:  99% 13.3M/13.5M [00:04<00:00, 3.02MB/s]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:04<00:00, 488kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:04<00:00, 2.90MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:04<00:00, 488kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:04<00:00, 2.90MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:04<00:00, 488kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  99% 13.4M/13.5M [00:04<00:00, 3.01MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt: 100% 13.5M/13.5M [00:04<00:00, 3.04MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:04<00:00, 469kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  99% 13.3M/13.5M [00:04<00:00, 3.00MB/s]
#
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-799927.pt:  99% 13.3M/13.5M [00:04<00:00, 2.88MB/s]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:04<00:00, 467kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:04<00:00, 2.77MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:04<00:00, 467kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:04<00:00, 2.77MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:04<00:00, 467kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt:  99% 13.4M/13.5M [00:04<00:00, 2.88MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt: 100% 13.5M/13.5M [00:04<00:00, 2.90MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:04<00:00, 449kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt:  99% 13.3M/13.5M [00:04<00:00, 2.87MB/s]
#
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-799927.pt:  99% 13.3M/13.5M [00:04<00:00, 2.76MB/s]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:04<00:00, 448kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:04<00:00, 2.66MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:04<00:00, 448kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:04<00:00, 2.66MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:04<00:00, 448kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt: 100% 13.5M/13.5M [00:04<00:00, 2.79MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt: 100% 13.5M/13.5M [00:04<00:00, 2.79MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:04<00:00, 430kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt: 100% 13.5M/13.5M [00:04<00:00, 2.79MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (25 / 25)    : 100% 190M/190M [00:07<00:00, 4.35MB/s, 26.0MB/s  ]
# New Data Upload               : 100% 163M/163M [00:07<00:00, 4.30MB/s, 22.3MB/s  ]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:04<00:00, 439kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:04<00:00, 2.61MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:04<00:00, 439kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:04<00:00, 2.61MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:04<00:00, 439kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt: 100% 13.5M/13.5M [00:04<00:00, 2.74MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt: 100% 13.5M/13.5M [00:04<00:00, 2.74MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:04<00:00, 422kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt: 100% 13.5M/13.5M [00:04<00:00, 2.74MB/s]
#
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-799927.pt: 100% 13.5M/13.5M [00:04<00:00, 2.63MB/s]
#
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:04<00:00, 430kB/s]
#
#
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:04<00:00, 2.55MB/s]
#
#
#
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:04<00:00, 430kB/s]
#
#
#
#
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:04<00:00, 2.55MB/s]
#
#
#
#
#
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:04<00:00, 430kB/s]
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-399962.pt: 100% 13.5M/13.5M [00:04<00:00, 2.68MB/s]
#
#
#
#
#
#
#
#   ...uggy2/Huggy/checkpoint.pt: 100% 13.5M/13.5M [00:04<00:00, 2.68MB/s]
#
#
#
#
#
#
#
#
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:04<00:00, 413kB/s]
#
#
#
#
#
#
#
#
#
#   ...gy2/Huggy/Huggy-999877.pt: 100% 13.5M/13.5M [00:04<00:00, 2.68MB/s]
#
#
#
#
#
#
#
#
#
#
# Processing Files (25 / 25)    : 100% 190M/190M [00:07<00:00, 24.2MB/s, 25.3MB/s  ]
# New Data Upload               : 100% 163M/163M [00:07<00:00, 20.8MB/s, 21.8MB/s  ]
#   .../Huggy/Huggy-1999925.onnx: 100% 2.27M/2.27M [00:05<00:00, 429kB/s]
#   ...y2/Huggy/Huggy-1999925.pt: 100% 13.5M/13.5M [00:05<00:00, 2.55MB/s]
#   .../Huggy/Huggy-2000047.onnx: 100% 2.27M/2.27M [00:05<00:00, 430kB/s]
#   ...y2/Huggy/Huggy-2000047.pt: 100% 13.5M/13.5M [00:05<00:00, 2.55MB/s]
#   ...2/Huggy/Huggy-399962.onnx: 100% 2.27M/2.27M [00:05<00:00, 430kB/s]
#   ...gy2/Huggy/Huggy-399962.pt: 100% 13.5M/13.5M [00:05<00:00, 2.68MB/s]
#   ...uggy2/Huggy/checkpoint.pt: 100% 13.5M/13.5M [00:05<00:00, 2.68MB/s]
#   ...results/Huggy2/Huggy.onnx: 100% 2.27M/2.27M [00:05<00:00, 413kB/s]
#   ...gy2/Huggy/Huggy-999877.pt: 100% 13.5M/13.5M [00:05<00:00, 2.68MB/s]
#   ...gy2/Huggy/Huggy-799927.pt: 100% 13.5M/13.5M [00:05<00:00, 2.57MB/s]
# [INFO] Your model is pushed to the hub. You can view your model here: https://huggingface.co/r-scoville/huggy-ppo

# %% [markdown]
# ---
#
# ## 9. Try out the trained model in the browser
#
# 1. Open the [Huggy game](https://huggingface.co/spaces/ThomasSimonini/Huggy) in the browser.
# 2. Click `Play with my Huggy model`.
# 3. Load the Huggy model:
# - Step 1: Enter username (`r-scoville`) and click `Search`.
# - Step 2: Select the Huggy model repository (`r-scoville/huggy-ppo`)
# - Step 3: Choose which model to play:
#   - For the most recent model, select `Huggy.onnx`.
#   - To see model progression along the training steps, select earlier models.
# - Click `Watch the agent play`.

# %% [markdown]
# ---
#
# *End of Huggy script*
